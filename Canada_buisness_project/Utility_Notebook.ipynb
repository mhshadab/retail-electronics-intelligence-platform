# %% [markdown]
# ##  **Test Api Key Vault**

# %%
# %pip install azure-identity azure-keyvault-secrets

# %%
Key = dbutils.secrets.get(scope = "fred-api-scope",key="fredkey")

# %%
dbutils.fs.ls("abfss://lakehouse@buisdatastore.dfs.core.windows.net/bronze/fred_raw/")

# %%
dbutils.fs.ls("abfss://lakehouse@buisdatastore.dfs.core.windows.net/bronze/fred_raw/DGS10/")
